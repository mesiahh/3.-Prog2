# %% [markdown]
# stack is good way in creating a palindrome
#
# has size and datatype
# could be array of int or char
#
#
#
# representation of stack
# // int size;
# // char data[10];
#
#
#
# struct - a technique to create datatype, when you need a datatype variable that is more than int float double char
# 	- creating a customized datatype
#
#
#
#
# struct stack{
# 	int size;
# 	char data[10];
# }
#
# main(){
# 	double blade;
# 	stack s;
# 	struct stack s;
# 	blade = 1.1
# 	s.size = 10;	// s variable from stack datatype stores both int and char array
# 	s.data[0] = a;
# }
#
#
#
#
#
# typedef is way to confuse programmer?
#
#
# // sample answers
# given an array
# [2][5][7][8][1]
#
# a. how would array look after 2 iterations using
#
#     1. bubblesort
#
#         2 5 7 8 1
#         2 5 7 1 8
#         2 5 1 7 8
#
#     2. insertion sort
#
#         2 5 7 8 1
#         2 5 7 8 1 // compares 2 and 5
#         2 5 7 8 1 // compares 5 and 7
#
#     3. selection sort
#
#         2 5 7 8 1
#         1 5 7 8 2
#         1 2 7 8 5

# %%
#include <stdio.h>
#include <stdlib.h>

struct stack{
	int size;
	char names[10][10];
};

int main(int argc, char *argv[]){
	
	struct stack s;
	s.size = 5;
	int x;
	
	for (x = 0; x < 5; x++){
		gets(s.names[x]);
	}
	
	
		
	for (x = 4; x >= 0; x--){
		printf("%s", s.names[x]);
	}
	
	printf("%i", s.size);	// %i for struct print 
	

	return 0;
}

# %%
#include <stdio.h>
#include <stdlib.h>
// pass string to function




void printThis(char city[], int code, float temperature){
    printf("%s\n", city);
    printf("%i\n", code);
    printf("%f\n", temperature);
}


main(){
    
    printThis("Cebu", 6000, 37.5);
}

# %%
//

#include <stdio.h>
#include <stdlib.h>
// pass string to function


struct place{
	char city[20];
	int code;
	float temperature;
};


void printThis(struct place templace){ // only 1 is called instead of the previous which is 3
    printf("%s\n", templace.city);
    printf("%i\n", templace.code);
    printf("%f\n", templace.temperature);
}


main(){
    struct place p;
    strcpy(p.city, "Cebu");
	p.code = 6000;
    p.temperature = 37.5;
    
    
    
    printThis(p);
    
}

# %%
#include <stdio.h>
#include <stdlib.h>
// pass string to function


typedef struct place{
	char city[20];
	int code;
	float temperature;
} p; // p becomes a global variables
    // not advisable


void printThis(){ // only 1 is called instead of the previous which is 3
    printf("%s\n", p.city);
    printf("%i\n", p.code);
    printf("%f\n", p.temperature);
}


main(){
    strcpy(p.city, "Cebu");
	p.code = 6000;
    p.temperature = 37.5;
    printThis(p);
}

# %% [markdown]
# insertion Sort- *Insertion sort in 2 mins yt
# bubblesort - swaps variables until there's nothing to be swapped least to greatest or greatest to least, depends on the condition in which bubblesort can be applied
# selection
