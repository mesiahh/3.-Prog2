# %%
# %% file 27-06malloc.c
#
# #include <stdio.h>
# #include <stdlib.h>
# // This program is an example of malloc
#
#
#
# int main(){
#     //This pointer holds the base address of the block created
#     int *ptr;
#     int n, i;
#     printf("Enter the number of elements: "); // input number of elements in array
#     scanf("%d", &n);
#     printf("Entered number of elements: %d\n", n);
#
#     ptr = (int*)malloc(n*sizeof(int)); // dynamically allocate memory using malloc()
#
#     // Check if memory has been successfully allocated by malloc or not
#     if(ptr == NULL){
#         printf("Memory not allocated.\n");
#         exit(0);
#     }
#     else{
#         printf("Memory successfully allocated using malloc.\n"); // memory successfully allocated
#         for(i = 0; i < n; ++i){ // get elements of the array
#             ptr[i] = i+1;
#         }
#         printf("The elements of the array are: "); // print the elements of the array
#         for (i = 0; i < n; ++i){
#             printf("%d ", ptr[ai]);
#         }
#
#     }
#     return 0;
# }

# %% [markdown]
# **Output**
#
#     Enter number of elements: 5
#
#     Memory successfully allocated using malloc.
#
#     The elements of the array are: 1, 2, 3, 4, 5,

# %% [markdown]
# <br>
#
# **C calloc()**
#
#     1. "calloc" known as "contaguous allocation" method in C is used to dynamically allocate the **specified** number of blocks of memory of the **specified type**. It is similar to malloc but has two different points:
#
#         - It initializes each block with a default value '0'.
#
#         - has two parameters or arguments compare to malloc().

# %% [markdown]
# <br>
#
# **Syntax of calloc()**
#
#     ptr = (cast-type*) calloc(n, element-size)
#
#         // n is the number of elemnts and element size is the size of each element

# %% [markdown]
# // Example
#
# **ptr = (float*)calloc(25,sizeof(float));**
#
# // This statement allocates contiguous space ion nmemory for 25 elements each with the size of the float.
#
# ![image.png](attachment:image.png)

# %%
# %% file 27-06calloc.c
#
# #include <stdio.h>
# #include <stdlib.h>
# // This program is an example of calloc
#
#
#
# int main(){
#     // This pointer hold the base address of block created
#     int * ptr;
#     int n, i;
#
#     // input number of elements for the array
#     n = 5;
#     printf("Enter the number of elements: %d\n", n);
#
#     // allocate memory using calloc()
#
#     ptr = (int*)calloc(n, sizeof(int));
#
#     if(ptr == NULL){
#         printf("Memory not allocated.\n");
#     }
#     else{
#         printf("Memory successfully allocated using calloc.\n");
#
#         // get elements of the array
#         for(i = 0; i < n; ++i){
#             ptr[i] = i + 1;
#         }
#
#         printf("The elemtents of the array are: ");
#         for (i = 0; i < n; ++i){
#             printf("%d, ", ptr[i]);
#
#         }
#     }

# %% [markdown]
# **Output**
#
#     Enter number of elements: 5
#
#     Memory successfully allocated using calloc.
#
#     The elements of the array are: 1, 2, 3, 4, 5,

# %% [markdown]
# <br>
#
# **C free() method**
#
# "free" method in C is used to dynamically de-allocate the memory. The memory allocated using functions malloc() and calloc() is not de-allocated on their own. Hence the free() method is used, whenever dynamic memory allocation takes place. It helps to reduce wastage of memory by freeing it.
#
# <br>
#
# **Syntax of free() in C**
#
# *free(ptr);*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %% 27-6free.c
#
# #include <stdio.h>
# #include <stdlib.h>
#
# int main(){
#     //pointer holds the base address of the block created
#     int * ptr, *ptr1;
#     int n, i;
#     // get num of elements in array
#     n = 5;
#     printf("Enter the number of elements: %d\n", n);
#
#     ptr = (int*)malloc(n * sizeof(int)) //Dynamically allocate memory using malloc()
#     ptr1 = (int*)calloc(n, sizeof(int)) // allocate memory using calloc()
#
#     if (ptr == NULL || ptr1 == NULL){
#         printf("Memory not allocated.\n");
#         exit(0);
#     }
#     else{
#         printf("Memory successfully allocated using malloc.\n");
#         // free memory
#         free(ptr);
#         printf("Malloc Memory Successully freed.\n");
#
#         printf("\nMemory successfully allocated using calloc.\n");
#
#         free(ptr1);
#         printf("Calloc Memory successfully freed.\n");
#     }
# }

# %% [markdown]
# **Output**
#
#     Enter number of elements: 5
#     Memory successfully allocated using malloc.
#     Malloc Memory successfully freed.
#
#     Memory successfully allocated using calloc.
#     Calloc Memory successfully freed.
#
#
#
#
#     https://www.geeksforgeeks.org/dynamic-memory-allocation-in-c-using-malloc-calloc-free-and-realloc/?ref=lbp

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
