# %% [markdown]
# # MIDTERM - JUNE 29 - SAT
#
#     arrays up to structures
#     structures will be discussed in 20-6-24
#     sortings will be included
#     Minimum of 4 items
#
#
# <!-- array that r
#
# 1 array for the qkwmelaksmlkdmaslkdmlkasm
#
#
# 1 static array
# dynamic array
#
#
# 1 dynamically allocated array
#
#
#
# each stage is a function call
# there
#
#  -->
#
#
# 3. unique value
# 4. palindrome with the unique values
# 5. one that sorts in chronoligal order

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %% file 18-06-24.c
# // SAMPLE 1
# // 1 and 2 was created yesterday
# // task - create function 3 - 5
#
# #include <stdio.h>
#
# int main(){
#     int input[10];
#
#     //int size = 0;
#     int output[10]; //int output[size];
#     printf("input 10 integers\n\n");
#     int i;
#     int j = 0;
#     int k;
#
#     //scanf loop
#     for (i = 0; i < 10; i++){ // ranges only 0 - 5
#         int booltrue = 0;
#         printf("index [%d] : ", i);
#         scanf("%d", &*(input + i));
#         if (*(input + i) > 5){
#             printf("Error");
#             break;
#         }
#         if (*(input + i) < 0){
#             printf("Error");
#             break;
#         }
#
#         for (k = 0;k < 10;k++){
#             if(*(input + k) == 3){
#                 booltrue++;
#                 break;
#             }
#         }
#         if(booltrue == 1){ // input[1] // should start at the first occurence of 3
#             if (*(input + i) <= 3){
#                 *(output + j) += *(input + i);
#                 //size += i;
#                 j++;
#             }
#         }
#     }
#     //output loop
#     printf("\n\nNew array: \n");
#     for(i = 0; i < j; i++){
#         printf("%d ", *(output + i));
#     }
# }

# %% [markdown]
# OUTPUT ACTIVITY

# %%
# %% file Case1.c
#
# // 1 and 2 was created yesterday
# // task - create function 3 - 5 and make 1 - 2 into a function
# #include <stdio.h>
#
# inputArr((int*) , (int*));
#
# int main(){
#     int input[10];
#     int output[10]; //int output[size];
#
#
#     inputArr((int*) input, (int*) output);
#
#
#     //output loop
#     printf("\n\nNew array: \n");
#     for(i = 0; i < j; i++){
#         printf("%d ", *(output + i));
#     }
# }
#
# // function 1
# void inputArr(int* input, int* output){
# 	printf("input 10 integers\n\n");
#     int i;
#     int j = 0;
#     int k;
#
#     //scanf loop
#     for (i = 0; i < 10; i++){ // ranges only 0 - 5
#         int booltrue = 0;
#         printf("index [%d] : ", i);
#         scanf("%d", &*(input + i));
#         outputArr((int*) input, (int*) output, i, j, k);
#     }
# }
#
# // function 2
# void outputArr(int* input, int* output, int i, int j, int k){
# 	    if (*(input + i) > 5){
#             printf("Error");
#             break;
#         }
#         if (*(input + i) < 0){
#             printf("Error");
#             break;
#         }
#
#         for (k = 0;k < 10;k++){
#             if(*(input + k) == 3){
#                 booltrue++;
#                 break;
#             }
#         }
#         if(booltrue == 1){ // input[1] // should start at the first occurence of 3
#             if (*(input + i) <= 3){
#                 *(output + j) += *(input + i);
#                 j++;
#             }
#         }
# }
# // function 3
# void uniqueLo(){ // function that prints unique values
#     int i, j;
#     for (i = 0; i < size, i++){
#         for (j = 0; j < size; j++){
#             if (arr[i] != arr[j] && i != j)
#         }
#     }
#
# }
# // function 4
# void palindrome(){ // a palindrome function we are making a palindrome not check if its a palindrome or not
#
# }
# // function 5
# void sortOrder(){
#
# }

# %%
# %% file Case2.c
#
# #include <stdio.h>
#
# void outputArr(int* input, int size) {
#     int sample[size]; // Adjusted to match the input size
#     int j = 0;
#     int booltrue = 0;
# 	int i;
# 	int k;
#     for (i = 0; i < size; i++) {
#         printf("%d ", *(input + i));
#         for (k = 0; k < size; k++) {
#             if (*(input + k) == 3) {
#                 booltrue++;
#                 break;
#             }
#         }
#         if (booltrue >= 1 && *(input + i) <= 3) { // Corrected condition
#             sample[j] = *(input + i); // Corrected assignment
#             j++;
#         }
#     }
#
#     printf("\n\nNew array: \n");
#     for (i = 0; i < j; i++) {
#         printf("%d ", sample[i]); // Corrected type specifier
#     }
# }
#
# int main() {
#     int input[10];
#     int size = 0;
# 	int i;
#     printf("input 10 integers\n\n");
#     for (i = 0; i < 10; i++) {
#         printf("index [%d] : ", i);
#         scanf("%d", &*(input + i));
#         if (*(input + i) > 5 || *(input + i) < 0) {
#             printf("Error\n");
#             break;
#         } else {
#             size++; // Count valid inputs
#         }
#     }
#
#     printf("\n\nInputted Array: \n");
#     for (i = 0; i < size; i++) {
#         printf("%d ", *(input + i));
#     }
#
#     outputArr(input, size); // Pass the input array and its size to the function
#
#     return 0;
# }

# %%
# %% file Case3True.c
#
# #include <stdio.h>
#
# void outputArr(int* input, int size) {
#     int sample[10]; // Assuming a maximum of 10 elements for simplicity
#     int j = 0;
#     int foundFirstThree = 0; // Flag to indicate the first occurrence of 3
# 	int i,k;
#     for (i = 0; i < size; i++) {
#         if (*(input + i) == 3 &&!foundFirstThree) {
#             foundFirstThree = 1; // Set flag once 3 is found
#         }
#
# 		if (foundFirstThree == 1 && *(input + i) <= 3) {
#             sample[j] = *(input + i); // Store the number in the sample array
#             j++;
#         }
#     }
#
#     printf("\n\nNew array: \n");
#     for (i = 0; i < j; i++) {
#         printf("%d ", sample[i]);
#     }
# }
#
# int main() {
#     int input[10];
#     int size = 0;
# 	int i;
#     printf("input 10 integers\n\n");
#     for (i = 0; i < 10; i++) {
#         printf("index [%d] : ", i);
#         scanf("%d", &*(input + i));
#         if (*(input + i) > 5 || *(input + i) < 0) {
#             printf("Error\n");
#             break;
#         } else {
#             size++; // Count valid inputs
#         }
#     }
#
#     printf("\n\nInputted Array: \n");
#     for (i = 0; i < size; i++) {
#         printf("%d ", *(input + i));
#     }
#
#     outputArr(input, size); // Pass the input array and its size to the function
#
#     return 0;
# }

# %%
# %% file Case3Revised.c
#
# // 2nd function complete
# // create 3. Unique 4. Palindrome 5. Sort
# #include <stdio.h>
#
# // 1 is not a function but 2
#
# int main(){
#     int input[10];
# 	int size = 0;
#     //int size = 0;
#     int i;
#
#     printf("input 10 integers\n\n");
#
# 	//scanf loop
#     for (i = 0; i < 10; i++){ // ranges only 0 - 5
#         printf("index [%d] : ", i);
#         scanf("%d", &*(input + i));
#
#         if (*(input + i) > 5 || *(input + i) < 0) {
#             printf("Error\n");
#             break;
#             return 0;
#         } else {
#             size++; // Count valid inputs
#         }
#     }
#
#
#     printf("\n\nInputted Array: \n");
#     for (i = 0; i < 10; i++){ // prints input array
#         printf("%d ", *(input + i));
#     }
#
# 	outputArr((int*) input, size); // function 2 implementation
#
#     //output loop
#
# }
#
#
#
#
# // function 2 prints any number ranges <= 3
# void outputArr(int* input, int size){ // something's wrong in function 2
# 	int sample[10];
# 	int i;
#     int j = 0;
#     int k;
#     int booltrue = 0;
#
# 	printf("\n\n");
# 	for (i = 0; i < size; i++){
# 		printf("%d ", *(input + i));
# 		//int booltrue = 0;
# 	            if(*(input + i) == 3 && !booltrue){
# 	                booltrue = 1;
# 	            }
#
# 	        if(booltrue == 1 && *(input + i) <= 3){ // condition should start at the first occurence of 3
# 	                *(sample + j) = *(input + i);
# 	                //size += i;
# 	                j++;
# 	        }
# 	}
# 	+
#
#
# 	printf("\n\nNew array: \n");
#     for(i = 0; i < j; i++){
#         printf("%d ", sample[i]);
#     }
# }

# %%
# %% file Case4Latest.c
#
# // 2nd function complete
# // create 3. Unique 4. Palindrome 5. Sort
# #include <stdio.h>
#
# // 1 is not a function but 2
# void outputArr(int*, int);
# void uniqueLo(int*, int);
#
#
# int main(){
#     int input[10];
# 	int size = 0;
#     //int size = 0;
#     int i;
#
#     printf("input 10 integers\n\n");
#
# 	//scanf loop
#     for (i = 0; i < 10; i++){ // ranges only 0 - 5
#         printf("index [%d] : ", i);
#         scanf("%d", &*(input + i));
#
#         if (*(input + i) > 5 || *(input + i) < 0) {
#             printf("Error\n");
#             break;
#             return 0;
#         } else {
#             size++; // Count valid inputs
#         }
#     }
#
#
#     printf("\n\nInputted Array: \n");
#     for (i = 0; i < 10; i++){ // prints input array
#         printf("%d ", *(input + i));
#     }
#
# 	outputArr((int*) input, size); // function 2 implementation
#
#     //output loop
#
# }
#
#
#
#
# // function 2 prints any number ranges <= 3
# void outputArr(int* input, int size){ // something's wrong in function 2
# 	int sample[10];
# 	int i;
#     int j = 0;
#     int k;
#     int booltrue = 0;
#
# 	printf("\n\n");
# 	for (i = 0; i < size; i++){
# 		printf("%d ", *(input + i));
# 		//int booltrue = 0;
# 	            if(*(input + i) == 3 && !booltrue){
# 	                booltrue = 1;
# 	            }
#
# 	        if(booltrue == 1 && *(input + i) <= 3){ // condition should start at the first occurence of 3
# 	                *(sample + j) = *(input + i);
# 	                //size += i;
# 	                j++;
# 	        }
# 	}
#
#
#
# 	printf("\n\nNew array: \n");
# 	int sample2[j];
#     for(i = 0; i < j; i++){
#         printf("%d ", sample[i]);
#         sample2[i] = sample[i];
#     }
#     uniqueLo((int*) sample2, j);
# }
#
# // function 3 find unique values
# void uniqueLo(int* sample2, int j){
# 	int i;
# 	printf("\n\nUnique Values: \n");
#     for (i = 0; i < j; i++){ // prints input array
#         printf("%d ", *(sample2 + i));
#     }
# }
#
# // function 4 create palindrome use 3 foor loops minimum 2
#
# // function 5 sort
#
# // plpease finish this code today and learn about malloc ty
