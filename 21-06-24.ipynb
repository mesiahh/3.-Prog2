# %%
# %% file 21-06-24_lastact.c
#
# #include <stdio.h>
# #include <stdlib.h>
#
# // Function prototypes
# void outputArr(int*, int);
# void uniqueLo(int*, int);
# void createPalindrome(int*, int);
# void sortArray(int*, int);
#
# int main() {
#     int input[10];
#     int size = 0;
#     int i;
#
#     printf("Input 10 integers (range 0 - 5)\n\n");
#
#     // Input loop
#     for (i = 0; i < 10; i++) {
#         printf("Index [%d] : ", i);
#         scanf("%d", &input[i]);
#
#         if (input[i] > 5 || input[i] < 0) {
#             printf("Error: Input out of range\n");
#             return 0;
#         } else {
#             size++; // Count valid inputs
#         }
#     }
#
#
#     outputArr(input, size); // Process and output the array
#
#     return 0;
# }
#
# // Function to process and output the array based on given condition
# void outputArr(int* input, int size) {
#     int sample[10];
#     int i, j = 0;
#     int booltrue = 0;
#
#     printf("\n\nProcessed Array (Values <= 3 starting from the first 3): \n");
#     for (i = 0; i < size; i++) {
#         printf("%d ", input[i]);
#         if (input[i] == 3) {
#             booltrue = 1;
#         }
#         if (booltrue && input[i] <= 3) {
#             sample[j++] = input[i];
#         }
#     }
#
#     printf("\n\nNew array: \n");
#     for (i = 0; i < j; i++) {
#         printf("%d ", sample[i]);
#     }
#
#     uniqueLo(sample, j);
# }
#
# // Function to find unique values
# void uniqueLo(int* sample2, int size) {
#     int* unique = (int*)malloc(size * sizeof(int));
#     int i, j, k, isUnique, uniqueSize = 0;
#
#     printf("\n\nUnique Values: \n");
#     for (i = 0; i < size; i++) {
#         isUnique = 1;
#         for (j = 0; j < uniqueSize; j++) {
#             if (sample2[i] == unique[j]) {
#                 isUnique = 0;
#                 break;
#             }
#         }
#         if (isUnique) {
#             unique[uniqueSize++] = sample2[i];
#         }
#     }
#
#     for (i = 0; i < uniqueSize; i++) {
#         printf("%d ", unique[i]);
#     }
#
#     createPalindrome(unique, uniqueSize);
#
#     free(unique);
# }
#
# // Function to create a palindrome
# void createPalindrome(int* unique, int size) {
#     int palindromeSize = 2 * size;
#     int* palindrome = (int*)malloc(palindromeSize * sizeof(int));
#     int i;
#
#     // Fill the palindrome array
#     for (i = 0; i < size; i++) {
#         palindrome[i] = unique[i];
#     }
#     for (i = size - 1; i >= 0; i--) {
#         palindrome[2 * size - 1 - i] = unique[i];
#     }
#
#     printf("\n\nPalindrome: \n");
#     for (i = 0; i < palindromeSize; i++) {
#         printf("%d ", palindrome[i]);
#     }
#
#     sortArray(palindrome, palindromeSize);
#
#     free(palindrome);
# }
#
# // Function to sort the array
# void sortArray(int* arr, int size) {
#     int i, j, temp;
#
#     for (i = 0; i < size - 1; i++) {
#         for (j = i + 1; j < size; j++) {
#             if (arr[i] > arr[j]) {
#                 temp = arr[i];
#                 arr[i] = arr[j];
#                 arr[j] = temp;
#             }
#         }
#     }
#
#     printf("\n\nSorted Array: \n");
#     for (i = 0; i < size; i++) {
#         printf("%d ", arr[i]);
#     }
# }

# %% [markdown]
# # Sorting Algorithms
#
# **Bubble Sort** - a simple comparison-based algorithm where each pair of adjacent elements is compared and the elements are swapped if they are in the wrong order. This process repeats until the list is sorted.
#
# Bubble Sort Example:

# %%
# %% file sortbubble.c
#
# void bubbleSort(int* arr, int size) {
#     int i, j, temp;
#     for (i = 0; i < size - 1; i++) {
#         for (j = 0; j < size - i - 1; j++) {
#             if (arr[j] > arr[j + 1]) {
#                 // Swap arr[j] and arr[j + 1]
#                 temp = arr[j];
#                 arr[j] = arr[j + 1];
#                 arr[j + 1] = temp;
#             }
#
#         }
#     }
# }

# %% [markdown]
# <br>
#
# **Insertion Sort** - builds the final sorted array one item at a time. It takes each element from the input data and finds the location it belongs within the sorted list and inserts it there.
#
# Insertion Sort Example:

# %%
# %% file sortbubble.c
#
# void insertionSort(int* arr, int size) {
#     int i, key, j;
#     for (i = 1; i < size; i++) {
#         key = arr[i];
#         j = i - 1;
#         // Move elements of arr[0..i-1], that are greater than key, to one position ahead of their current position
#         while (j >= 0 && arr[j] > key) {
#             arr[j + 1] = arr[j];
#             j = j - 1;
#         }
#         arr[j + 1] = key;
#     }
# }

# %% [markdown]
# <br>
#
# **Structures in C**
#
# A structure in C is a user-defined data type that groups related variables of different data types into a single unit.
#
# Defining and Using a Structure:

# %%
#include <stdio.h>

// Define a structure named 'Person'
struct Person {
    char name[50];
    int age;
    float height;
};

int main() {
    // Declare a variable of type 'Person'
    struct Person person1;

    // Access and assign values to the structure members
    printf("Enter name: ");
    scanf("%s", person1.name);
    printf("Enter age: ");
    scanf("%d", &person1.age);
    printf("Enter height: ");
    scanf("%f", &person1.height);

    // Print the values
    printf("\nName: %s\nAge: %d\nHeight: %.2f\n", person1.name, person1.age, person1.height);

    return 0;
}

# %% [markdown]
# <br>
#
# **Accessing Structure Members:**
#
# Dot Operator (.): Used to access members of a structure variable.
# Arrow Operator (->): Used to access members of a structure through a pointer to the structure.
#
# Example of Accessing Structure Members:

# %%
# %% file acccessstrucmem.c
#
# #include <stdio.h>
#
# // Define a structure named 'Person'
# struct Person {
#     char name[50];
#     int age;
#     float height;
# };
#
# int main() {
#     struct Person person1;
#     struct Person* ptr = &person1;
#
#     // Access members using dot operator
#     person1.age = 30;
#     printf("Age using dot operator: %d\n", person1.age);
#
#     // Access members using arrow operator
#     ptr->height = 5.9;
#     printf("Height using arrow operator: %.2f\n", ptr->height);
#
#     return 0;
# }

# %%
# %% file latest123.c
#
# #include <stdio.h>
# #include <stdlib.h>
#
# // Function prototypes
# void outputArr(int*, int);
# void uniqueLo(int*, int);
# void createPalindrome(int*, int);
# void bubbleSort(int*, int);
#
# int main() {
#     int input[10];
#     int size = 0;
#     int i;
#
#     printf("Input 10 integers (range 0 - 5)\n\n");
#
#     // Input loop
#     for (i = 0; i < 10; i++) {
#         printf("Index [%d] : ", i);
#         scanf("%d", &input[i]);
#
#         if (input[i] > 5 || input[i] < 0) {
#             printf("Error: Input out of range\n");
#             return 0;
#         } else {
#             size++; // Count valid inputs
#         }
#     }
#
#     printf("\n\nInputted Array: \n");
#     for (i = 0; i < size; i++) { // Print input array
#         printf("%d ", input[i]);
#     }
#
#     outputArr(input, size); // Process and output the array
#
#     return 0;
# }
#
# // Function to process and output the array based on given condition
# void outputArr(int* input, int size) {
#     int sample[10];
#     int i, j = 0;
#     int booltrue = 0;
#
#     printf("\n\nProcessed Array (Values <= 3 starting from the first 3): \n");
#     for (i = 0; i < size; i++) {
#         printf("%d ", input[i]);
#         if (input[i] == 3) {
#             booltrue = 1;
#         }
#         if (booltrue && input[i] <= 3) {
#             sample[j++] = input[i];
#         }
#     }
#
#     printf("\n\nNew array: \n");
#     for (i = 0; i < j; i++) {
#         printf("%d ", sample[i]);
#     }
#
#     uniqueLo(sample, j);
# }
#
# // Function to find unique values
# void uniqueLo(int* sample2, int size) {
#     int* unique = (int*)malloc(size * sizeof(int));
#     int i, j, k, isUnique, uniqueSize = 0;
#
#     printf("\n\nUnique Values: \n");
#     for (i = 0; i < size; i++) {
#         isUnique = 1;
#         for (j = 0; j < uniqueSize; j++) {
#             if (sample2[i] == unique[j]) {
#                 isUnique = 0;
#                 break;
#             }
#         }
#         if (isUnique) {
#             unique[uniqueSize++] = sample2[i];
#         }
#     }
#
#     for (i = 0; i < uniqueSize; i++) {
#         printf("%d ", unique[i]);
#     }
#
#     createPalindrome(unique, uniqueSize);
#
#     free(unique);
# }
#
# // Function to create a palindrome
# void createPalindrome(int* unique, int size) {
#     int palindromeSize = 2 * size;
#     int* palindrome = (int*)malloc(palindromeSize * sizeof(int));
#     int i;
#
#     // Fill the palindrome array
#     for (i = 0; i < size; i++) {
#         palindrome[i] = unique[i];
#     }
#     for (i = size - 1; i >= 0; i--) {
#         palindrome[2 * size - 1 - i] = unique[i];
#     }
#
#     printf("\n\nPalindrome: \n");
#     for (i = 0; i < palindromeSize; i++) {
#         printf("%d ", palindrome[i]);
#     }
#
#     bubbleSort(palindrome, palindromeSize);
#
#     free(palindrome);
# }
#
# // Bubble sort function
# void bubbleSort(int* arr, int size) {
#     int i, j, temp;
#     for (i = 0; i < size - 1; i++) {
#         for (j = 0; j < size - i - 1; j++) {
#             if (arr[j] > arr[j + 1]) {
#                 // Swap arr[j] and arr[j + 1]
#                 temp = arr[j];
#                 arr[j] = arr[j + 1];
#                 arr[j + 1] = temp;
#             }
#         }
#     }
#
#     printf("\n\nSorted Array: \n");
#     for (i = 0; i < size; i++) {
#         printf("%d ", arr[i]);
#     }
# }

# %% [markdown]
# # Strings

# %% [markdown]
# *pls refer to prog 1 notes*
#
# an array of characters
#
# dont forget to add #include <strings.h>
#
# fgets()

# %% [markdown]
# //This program is purely only string no malloc, calloc, pure string
#
# 1.) Input Name
#
# 2.) " M.N // Middle Name
#
# 3.) " F. N // Family Name
#
# 4.) Print in Alphabetical order
#
# comparing three strings
#
# 5.) Sort Each String
#         ex: OSCAR
#         output: ACORS
#
#
# 6.) Compress
#         ex: OSCARR
#         output: A[1]C[1]O[1]R[2]S[1]

# %%
#include <stdio.h>
#include <string.h>
int i, j;
// Function to swap two characters
void swap(char *x, char *y) {
    char temp;
    temp = *x;
    *x = *y;
    *y = temp;
}

// Function to sort a string
void sortString(char str[]) {
	
    int len = strlen(str);
    for (i = 0; i < len - 1; i++) {
        for (j = 0; j < len - i - 1; j++) {
            if (str[j] > str[j + 1]) {
                swap(&str[j], &str[j + 1]);
            }
        }
    }
}

// Function to compress a string
void compressString(char str[]) {
    int len = strlen(str);
    for (i = 0; i < len - 1; i++) {
        if (str[i] == str[i + 1]) {
            continue;
        } else {
            printf("%c[%d", str[i], 1);
            for (j = i + 1; j < len && str[i] == str[j]; j++);
            printf("]"); // Close the compression tag
            i = j - 1; // Skip the rest of the loop for the current iteration
        }
    }
    printf("%c\n", str[len - 1]); // Print the last character separately
}


void printName(char* fam, char* mid, char* name){
	printf("Name: \n\t %s, %s %s\n\n", fam, name, mid);
}
int main() {
    char name[20], mid[20], fam[20];

    printf("Input 1st Name: ");
    scanf("%19s", name);
    getchar();

    printf("\nInput Middle Name: ");
    scanf("%19s", mid);
    getchar();

    printf("\nInput Family Name: ");
    scanf("%19s", fam);
    getchar();
	
	
	printName(fam, mid, name);
    // Sort each string
    sortString(name);
    sortString(mid);
    sortString(fam);

    // Print sorted names
    printf("Sorted Names:\n");
    printf("Name: %s\n", name);
    printf("Middle Name: %s\n", mid);
    printf("Family Name: %s\n", fam);

    // Compress each string
    printf("Compressed Names:\n");
    compressString(name);
    compressString(mid);
    compressString(fam);

    return 0;
}

# %% [markdown]
# int * ptr = (int*) malloc (sizeof(int)*5);
#
# // int pointer
#
# // array points to a pointer of a specific array
#
# int arr[5] - points to the first collection of hte number of ints
# int i;
#
#
# for (i = 0; i < arr; i++){
#
#
#     //prints invalid
# }
#
# malloc
# calloc
# realloc
#
#
#
#  // str

# %% [markdown]
# # **NEW ACTIVITY**
#
# // purely arrays and strings no sorting
#
# **RIDDLE**
#
# Dreaded doom darkening skies above // string1
#
# Ravenous red raven a rising legend // string2
#
# Ancient Arcane creature of great destruction //string3
#
# Great Greedy source of upheaval // string4
#
# Ominous Winged Overlord with scales of iron // string5
#
# Nightmare of the realm and devourer of nations // string6
#
#
# <br>
#
# **OUTPUT SHOULD BE**
#
# first letter of the last word of each string
#
# DRAGON ALDUIN
#
# Diamonds: # of words in the riddle
#
# Rubies: # of r/Rs
#
# Emerald: # of words with letters < 4
#
# Gold: # of vowels
#
# Silver: # of consonants
#
# Copper: # of spaces

# %%
# %% file pinakalatestrevised.c
#
# #include <stdio.h>
# #include <string.h>
# int i, j;
#
# // number 4 function
# void printName(char* fam, char* mid, char* name) {
#     printf("\n\nName in Alphabetical Order: \n\n\t");
#     char input1[20], input2[20], input3[20];
#
#     // Sort the names directly using strcmp
#     if (strcmp(name, fam) < 0 && strcmp(name, mid) < 0) {
#         strcpy(input1, name);
#         if (strcmp(fam, mid) < 0) {
#             strcpy(input2, fam);
#             strcpy(input3, mid);
#         } else {
#             strcpy(input2, mid);
#             strcpy(input3, fam);
#         }
#     } else if (strcmp(fam, mid) < 0 && strcmp(fam, name) < 0) {
#         strcpy(input1, fam);
#         if (strcmp(mid, name) < 0) {
#             strcpy(input2, mid);
#             strcpy(input3, name);
#         } else {
#             strcpy(input2, name);
#             strcpy(input3, mid);
#         }
#     } else if (strcmp(mid, fam) < 0 && strcmp(mid, name) < 0) {
#         strcpy(input1, mid);
#         if (strcmp(fam, name) < 0) {
#             strcpy(input2, fam);
#             strcpy(input3, name);
#         } else {
#             strcpy(input2, name);
#             strcpy(input3, fam);
#         }
#     }
#
#     // Output the sorted names
#     printf("\n\n");
#     printf("%s %s %s\n\n", input1, input2, input3);
# }
#
#
# // #5 function sort
# void sortString(char str[]) {
#     int len = strlen(str);
#     for (i = 0; i < len - 1; i++) {
#         for (j = 0; j < len - i - 1; j++) {
#             if (str[j] > str[j + 1]) {
#                 char temp = str[j];
#                 str[j] = str[j + 1];
#                 str[j + 1] = temp;
#             }
#         }
#     }
# }
#
# // #6 compress
# // Function to compress a string
# void compressString(char str[]) {
#     int len = strlen(str);
#     for (i = 0; i < len - 1; i++) {
#         if (str[i] == str[i + 1]) {
#             continue;
#         } else {
#             printf("%c[%d", str[i], 1);// there's a problem here pls fix
#             for (j = i + 1; j < len && str[i] == str[j]; j++);
#             printf("]"); // Close the compression tag
#             i = j - 1; // Skip the rest of the loop for the current iteration
#         }
#     }
#     printf("%c\n", str[len - 1]); // Print the last character separately
# }
#
#
#
#
#
#
#
#
# int main() {
#     char name[20], mid[20], fam[20];
#
#     printf("Input 1st Name: ");
#     scanf("%19s", name);
#     getchar();
#
#     printf("\nInput Middle Name: ");
#     scanf("%19s", mid);
#     getchar();
#
#     printf("\nInput Family Name: ");
#     scanf("%19s", fam);
#     getchar();
#
# 	// number 4
# 	printName(fam, mid, name);
#
#
#
# 	// number 5 Sort each string
#     sortString(name);
#     sortString(mid);
#     sortString(fam);
#
#     // Print sorted names
#     printf("Sorted Names:\n");
#     printf("Name: %s\n", name);
#     printf("Middle Name: %s\n", mid);
#     printf("Family Name: %s\n", fam);
#
#     // Compress each string
#     printf("Compressed Names:\n");
#     compressString(name);
#     compressString(mid);
#     compressString(fam);
#
#     return 0;
# }
#
# //focus on array and string manipulation
#
# // monday sorting
# // exam doesn't have sorting only 1
#
# // master 2
#
# // dynamically
